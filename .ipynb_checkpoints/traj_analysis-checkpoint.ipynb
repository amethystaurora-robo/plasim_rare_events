# %%
import pandas as pd
import numpy as np
import xarray as xr
import seaborn as sns
import netCDF4 as nc
import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
amoc_data = pd.read_csv('amoc_averaged.txt',sep='\t', header=None, names=["AMOC", "Year", "Trajectory"])

# %%
amoc_monthly = pd.read_csv('amoc_monthly.txt',sep='\t', header=None, names=["AMOC", "Year", "Month", "Trajectory"])

# %%
amoc_monthly.head()
# Out:
#                                                 AMOC  Year        Month  \
# 0  Monthly AMOC Index (NADW)\Year\Month\Trajector...   NaN          NaN
# 1                                           20.41133   1.0  10-Feb-1804
# 2                                           17.13166   1.0  20-Feb-1804
# 3                                           21.19438   1.0  30-Feb-1804
# 4                                           19.00060   1.0  10-Mar-1804
#
#    Trajectory
# 0         NaN
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
monthly_data = amoc_monthly.iloc[1:,]
monthly_data.head()
# Out:
#        AMOC  Year        Month  Trajectory
# 1  20.41133   1.0  10-Feb-1804         1.0
# 2  17.13166   1.0  20-Feb-1804         1.0
# 3  21.19438   1.0  30-Feb-1804         1.0
# 4  19.00060   1.0  10-Mar-1804         1.0
# 5  17.91331   1.0  20-Mar-1804         1.0

# %%
print(len(monthly_data))
print(20*12*100)
print(monthly_data['Month'])
# Out:
# 71280
# 24000
# 1            NaN
# 2            1.0
# 3            2.0
# 4            3.0
# 5            4.0
#           ...
# 71276    71275.0
# 71277    71276.0
# 71278    71277.0
# 71279    71278.0
# 71280    71279.0
# Name: Month, Length: 71280, dtype: float64

# %%
amoc_data.head()
# Out:
#                                             AMOC  Year  Trajectory
# 0  Averaged AMOC Index (NADW)\Year\Trajectory ID   NaN         NaN
# 1                                        19.6229   1.0         1.0
# 2                                        19.4233   1.0         2.0
# 3                                        19.3161   1.0         3.0
# 4                                        19.7528   1.0         4.0

# %%
amoc = amoc_data.iloc[1:,]
amoc.head()
# Out:
#       AMOC  Year  Trajectory
# 1  19.6229   1.0         1.0
# 2  19.4233   1.0         2.0
# 3  19.3161   1.0         3.0
# 4  19.7528   1.0         4.0
# 5   19.544   1.0         5.0

# %%
amoc['AMOC']=amoc['AMOC'].astype(float)
# Out:
# /var/folders/v1/ymptnwwx3x1b7_mw0nns09wr0000gn/T/ipykernel_59836/1453111854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amoc['AMOC']=amoc['AMOC'].astype(float)

# %%
plt.figure(figsize=(10,6))
colors = ['#7abe80','#ffbdbd', '#658e93', '#45954c']
sns.set_palette(sns.color_palette(colors))
sns.set_style("darkgrid")
sns.lineplot(data=amoc, x="Year", y="AMOC", hue="Trajectory",
             alpha=0.8, linewidth=0.5, legend=False)
plt.ylabel("AMOC (Sv)")
plt.title('Trajectory Spread of AMOC Indices over 20 Years')
#plt.show()
plt.savefig("AMOC_traj_spread.png")

# %%
#control run (1804.01) value of AMOC is equal to 19.51
new_data = monthly_data.loc[monthly_data['Year']<6]
plt.figure(figsize=(10,6))
colors = ['#7abe80','#ffbdbd', '#658e93', '#45954c']
sns.set_palette(sns.color_palette(colors))
sns.set_style("darkgrid")
sns.lineplot(data=new_data, x="Month", y="AMOC",
             alpha=0.8, linewidth=0.5, legend=False)
plt.ylabel("AMOC (Sv)")
plt.title('Trajectory Spread of AMOC Indices over 20 Years')
#plt.show()
plt.savefig("AMOC_monthly_spread.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 7
#       5 sns.set_palette(sns.color_palette(colors))
#       6 sns.set_style("darkgrid")
# ----> 7 sns.lineplot(data=new_data, x="Month", y="AMOC",
#       8              alpha=0.8, linewidth=0.5, legend=False)
#       9 plt.ylabel("AMOC (Sv)")
#      10 plt.title('Trajectory Spread of AMOC Indices over 20 Years')
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/seaborn/relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/seaborn/relational.py:372, in _LinePlotter.plot(self, ax, kws)
#     369                     obj.set_capstyle(line_capstyle)
#     371 # Finalize the axes details
# --> 372 self._add_axis_labels(ax)
#     373 if self.legend:
#     374     legend_artist = partial(mpl.lines.Line2D, xdata=[], ydata=[])
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/seaborn/_base.py:1199, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
# -> 1199     y_visible = any(t.get_visible() for t in ax.get_yticklabels())
#    1200     ax.set_ylabel(self.variables.get("y", default_y), visible=y_visible)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:1508, in Axis.get_ticklabels(self, minor, which)
#    1506 if minor:
#    1507     return self.get_minorticklabels()
# -> 1508 return self.get_majorticklabels()
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:1465, in Axis.get_majorticklabels(self)
#    1463 def get_majorticklabels(self):
#    1464     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1465     self._update_ticks()
#    1466     ticks = self.get_major_ticks()
#    1467     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:1294, in Axis._update_ticks(self)
#    1292 major_locs = self.get_majorticklocs()
#    1293 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1294 major_ticks = self.get_major_ticks(len(major_locs))
#    1295 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1296     tick.update_position(loc)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:1675, in Axis.get_major_ticks(self, numticks)
#    1671     numticks = len(self.get_majorticklocs())
#    1673 while len(self.majorTicks) < numticks:
#    1674     # Update the new tick label properties from the old.
# -> 1675     tick = self._get_tick(major=True)
#    1676     self.majorTicks.append(tick)
#    1677     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:1603, in Axis._get_tick(self, major)
#    1599     raise NotImplementedError(
#    1600         f"The Axis subclass {self.__class__.__name__} must define "
#    1601         "_tick_class or reimplement _get_tick()")
#    1602 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:429, in YTick.__init__(self, *args, **kwargs)
#     428 def __init__(self, *args, **kwargs):
# --> 429     super().__init__(*args, **kwargs)
#     430     # x in axes coords, y in data coords
#     431     ax = self.axes
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/axis.py:159, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     152 grid_kw = {k[5:]: v for k, v in kwargs.items()}
#     154 self.tick1line = mlines.Line2D(
#     155     [], [],
#     156     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     157     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     158 )
# --> 159 self.tick2line = mlines.Line2D(
#     160     [], [],
#     161     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     162     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     163 )
#     164 self.gridline = mlines.Line2D(
#     165     [], [],
#     166     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     167     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     168     **grid_kw,
#     169 )
#     170 self.gridline.get_path()._interpolation_steps = \
#     171     GRIDLINE_INTERPOLATION_STEPS
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/lines.py:426, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     423 self._subslice = False
#     424 self._x_filled = None  # used in subslicing; only x is needed
# --> 426 self.set_data(xdata, ydata)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/lines.py:667, in Line2D.set_data(self, *args)
#     664     x, y = args
#     666 self.set_xdata(x)
# --> 667 self.set_ydata(y)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/matplotlib/lines.py:1310, in Line2D.set_ydata(self, y)
#    1308 if not np.iterable(y):
#    1309     raise RuntimeError('y must be a sequence')
# -> 1310 self._yorig = copy.copy(y)
#    1311 self._invalidy = True
#    1312 self.stale = True
#
# KeyboardInterrupt:

# %%
stats = amoc.groupby("Year")["AMOC"].agg(Mean_AMOC="mean", Std_AMOC="std").reset_index()
plt.figure(figsize=(10,6))
plt.plot(stats["Year"], stats["Mean_AMOC"], color="black", label="Ensemble mean")
plt.fill_between(stats["Year"],
                 stats["Mean_AMOC"] - stats["Std_AMOC"],
                 stats["Mean_AMOC"] + stats["Std_AMOC"],
                 color="gray", alpha=0.3, label="±1 std")
plt.xlabel("Year")
plt.ylabel("AMOC (Sv)")
plt.legend()
plt.show()

# %%
# compute std dev for each year
std_per_year = amoc.groupby("Year")["AMOC"].std().reset_index()

# plot
plt.figure(figsize=(10,6))
plt.plot(std_per_year["Year"], std_per_year["AMOC"], color="blue", marker="o", linewidth=2)
plt.xlabel("Year")
plt.ylabel("Standard deviation of AMOC (Sv)")
plt.title("AMOC ensemble standard deviation over time")
plt.grid(True)
#plt.show()
plt.savefig("AMOC_std_dev.png")

# %%
sst_df = sst_traj_one.to_dataframe()

# %%
sst_df = sst_df.reset_index()

# %%
print(sst_df['time_bnds'].unique())
for col in sst_df.columns:
    print(col)
sst_df.head()
# Out:
# [1.0101000e+04 1.0130000e+04 1.0201000e+04 1.0230000e+04 1.0301000e+04
#  1.0330000e+04 1.0401000e+04 1.0430000e+04 1.0501000e+04 1.0530000e+04
#  1.0601000e+04 1.0630000e+04 1.0701000e+04 1.0730000e+04 1.0801000e+04
#  1.0830000e+04 1.0901000e+04 1.0930000e+04 1.1001000e+04 1.1030000e+04
#  1.1101000e+04 1.1130000e+04 1.1201000e+04 1.1230000e+04 3.8800201e+07
#  3.8800230e+07 3.8800301e+07 3.8800330e+07 3.8800401e+07 3.8800430e+07
#  3.8800501e+07 3.8800530e+07 3.8800601e+07 3.8800630e+07 3.8800701e+07
#  3.8800730e+07 3.8800801e+07 3.8800830e+07 3.8800901e+07 3.8800930e+07
#  3.8801001e+07 3.8801030e+07 3.8801101e+07 3.8801130e+07 3.8801201e+07
#  3.8801230e+07 3.8810101e+07 3.8810130e+07 3.9800201e+07 3.9800230e+07
#  3.9800301e+07 3.9800330e+07 3.9800401e+07 3.9800430e+07 3.9800501e+07
#  3.9800530e+07 3.9800601e+07 3.9800630e+07 3.9800701e+07 3.9800730e+07
#  3.9800801e+07 3.9800830e+07 3.9800901e+07 3.9800930e+07 3.9801001e+07
#  3.9801030e+07 3.9801101e+07 3.9801130e+07 3.9801201e+07 3.9801230e+07
#  3.9810101e+07 3.9810130e+07 4.0790201e+07 4.0790230e+07 4.0790301e+07
#  4.0790330e+07 4.0790401e+07 4.0790430e+07 4.0790501e+07 4.0790530e+07
#  4.0790601e+07 4.0790630e+07 4.0790701e+07 4.0790730e+07 4.0790801e+07
#  4.0790830e+07 4.0790901e+07 4.0790930e+07 4.0791001e+07 4.0791030e+07
#  4.0791101e+07 4.0791130e+07 4.0791201e+07 4.0791230e+07 4.0800101e+07
#  4.0800130e+07 4.1790201e+07 4.1790230e+07 4.1790301e+07 4.1790330e+07
#  4.1790401e+07 4.1790430e+07 4.1790501e+07 4.1790530e+07 4.1790601e+07
#  4.1790630e+07 4.1790701e+07 4.1790730e+07 4.1790801e+07 4.1790830e+07
#  4.1790901e+07 4.1790930e+07 4.1791001e+07 4.1791030e+07 4.1791101e+07
#  4.1791130e+07 4.1791201e+07 4.1791230e+07 4.1800101e+07 4.1800130e+07]
# time
# bnds
# lon
# lat
# time_bnds
# tas
#       time  bnds  lon        lat  time_bnds         tas
# 0  10115.5     0  0.0  85.760587    10101.0  235.281357
# 1  10115.5     0  0.0  80.268779    10101.0  237.005051
# 2  10115.5     0  0.0  74.744540    10101.0  248.992569
# 3  10115.5     0  0.0  69.212976    10101.0  261.197845
# 4  10115.5     0  0.0  63.678636    10101.0  270.136078

# %%
sst_df.head()
print(len(sst_df))
print(sst_df['year'].unique())
# Out:
# 442368
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 3
#       1 sst_df.head()
#       2 print(len(sst_df))
# ----> 3 print(sst_df['year'].unique())
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
#get just the year
#make a list of unique time_bnds
def make_bounds(df):

    df['year'] = df['time_bnds'].astype(str).str[:4]
    time_bnds_list = df['year'].unique()
    print("Length of years",len(time_bnds_list))
    bounds=[]
    #print length of list
    for time in time_bnds_list:
        bound = df.loc[df['year']==time]
        bounds.append(len(bound))
    #make a new column with a counter, changing at each end of list
    print("Length of list of lengths",len(bounds))
    values=[]
    #get length of bounds
    print("first element in length list:",bounds[0],"second element in length list:",bounds[1])
    bound_length = bounds[0] + bounds[1]
    end_term = int(len(bounds)/3+1)
    for i in range(1, end_term):
        values += [i] * bound_length
    return values

# %%
#get just the year for other trajectory where year is different
#make a list of unique time_bnds
def make_bounds(df):

    df['year'] = df['time']//1000
    time_bnds_list = df['year'].unique()
    print("time bounds list:",time_bnds_list)
    print("Length of years",len(time_bnds_list))
    bounds=[]
    #print length of list
    for time in time_bnds_list:
        bound = df.loc[df['year']==time]
        print(bound)
        bounds.append(len(bound))
    #make a new column with a counter, changing at each end of list
    print("Length of list of lengths",len(bounds))
    values=[]
    #get length of bounds
    print("first element in length list:",bounds[0],"second element in length list:",bounds[1])
    bound_length = bounds[0] + bounds[1]
    end_term = int(len(bounds)/3+1)
    for i in range(1, end_term):
        values += [i] * bound_length
    return values

# %%
sst_df['Year Counter'] = values

# %%
weights = np.cos(np.deg2rad(sst_df['lat']))
sst_df['weighted_tas'] = sst_df['tas'] * weights

# %%
sns.lineplot(data=sst_df,x='Year Counter',y='weighted_tas',errorbar=None)
# Out:
# <Axes: xlabel='Year Counter', ylabel='weighted_tas'>

# %%
#ensemble spread and std dev
folder_path='100traj_5year/'
plt.figure()
traj_counter=0
ensemble_list=[]
for file in os.listdir(folder_path):
    if file.endswith(".nc"):
        print(file)
        sst_annual=xr.open_dataset(os.path.join(folder_path, file))
        weights = np.cos(np.deg2rad(sst_annual['lat']))
        
        tas_global = (
            sst_annual['tas']
            .weighted(weights)
            .mean(dim=('lat', 'lon'))
        )
        tas_weighted=tas_global.to_dataframe()
        reset=tas_weighted.reset_index()
        reset['Year Counter'] = make_bounds(reset)
        #weights = np.cos(np.deg2rad(reset['lat']))
        #reset['weighted_tas'] = reset['tas'] * weights
        sns.lineplot(data=reset,x='Year Counter',y='tas',errorbar=None)
        reset['Trajectory ID']=traj_counter
        traj_counter+=1
        ensemble_list.append(reset)
plt.show()
plt.close()
reset.head()
# Out:
# tas_traj0073.nc
# time bounds list: [1.0000e+01 1.1000e+01 3.8800e+04 3.8801e+04 3.8810e+04 3.9800e+04
#  3.9801e+04 3.9810e+04 4.0790e+04 4.0791e+04 4.0800e+04 4.1790e+04
#  4.1791e+04 4.1800e+04]
# Length of years 14
#       time         tas  year
# 0  10115.5  282.326668  10.0
# 1  10215.5  283.049968  10.0
# 2  10315.5  283.957680  10.0
# 3  10415.5  285.223913  10.0
# 4  10515.5  286.666988  10.0
# 5  10615.5  287.587739  10.0
# 6  10715.5  287.608266  10.0
# 7  10815.5  287.298698  10.0
# 8  10915.5  286.754597  10.0
#        time         tas  year
# 9   11015.5  285.478223  11.0
# 10  11115.5  284.419734  11.0
# 11  11215.5  283.250284  11.0
#           time         tas     year
# 12  38800215.5  280.851777  38800.0
# 13  38800315.5  281.427474  38800.0
# 14  38800415.5  282.657670  38800.0
# 15  38800515.5  284.100353  38800.0
# 16  38800615.5  285.157977  38800.0
# 17  38800715.5  285.602208  38800.0
# 18  38800815.5  285.540994  38800.0
# 19  38800915.5  285.020807  38800.0
#           time         tas     year
# 20  38801015.5  283.834988  38801.0
# 21  38801115.5  282.397257  38801.0
# 22  38801215.5  281.565030  38801.0
#           time         tas     year
# 23  38810115.5  280.726717  38810.0
#           time         tas     year
# 24  39800215.5  280.851759  39800.0
# 25  39800315.5  281.497423  39800.0
# 26  39800415.5  282.634273  39800.0
# 27  39800515.5  284.104384  39800.0
# 28  39800615.5  285.234761  39800.0
# 29  39800715.5  285.692669  39800.0
# 30  39800815.5  285.587412  39800.0
# 31  39800915.5  285.106663  39800.0
#           time         tas     year
# 32  39801015.5  283.664858  39801.0
# 33  39801115.5  282.408334  39801.0
# 34  39801215.5  281.369072  39801.0
#           time         tas     year
# 35  39810115.5  280.690273  39810.0
#           time         tas     year
# 36  40790215.5  280.702291  40790.0
# 37  40790315.5  281.361849  40790.0
# 38  40790415.5  282.687515  40790.0
# 39  40790515.5  284.206022  40790.0
# 40  40790615.5  285.421036  40790.0
# 41  40790715.5  285.822714  40790.0
# 42  40790815.5  285.856660  40790.0
# 43  40790915.5  285.217182  40790.0
#           time         tas     year
# 44  40791015.5  284.039248  40791.0
# 45  40791115.5  282.778333  40791.0
# 46  40791215.5  281.502491  40791.0
#           time        tas     year
# 47  40800115.5  280.60575  40800.0
#           time         tas     year
# 48  41790215.5  280.846068  41790.0
# 49  41790315.5  281.404420  41790.0
# 50  41790415.5  282.825237  41790.0
# 51  41790515.5  284.285734  41790.0
# 52  41790615.5  285.403499  41790.0
# 53  41790715.5  286.003698  41790.0
# 54  41790815.5  285.802534  41790.0
# 55  41790915.5  285.036474  41790.0
#           time         tas     year
# 56  41791015.5  283.989358  41791.0
# 57  41791115.5  282.479317  41791.0
# 58  41791215.5  281.351817  41791.0
#           time         tas     year
# 59  41800115.5  280.644553  41800.0
# Length of list of lengths 14
# first element in length list: 9 second element in length list: 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[222], line 19
#      17 tas_weighted=tas_global.to_dataframe()
#      18 reset=tas_weighted.reset_index()
# ---> 19 reset['Year Counter'] = make_bounds(reset)
#      20 #weights = np.cos(np.deg2rad(reset['lat']))
#      21 #reset['weighted_tas'] = reset['tas'] * weights
#      22 sns.lineplot(data=reset,x='Year Counter',y='tas',errorbar=None)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)
#    4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)
#    5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File ~/opt/anaconda3/envs/plasim/lib/python3.10/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (48) does not match length of index (60)

# %%
ensemble['tas'].dtype
# Out:
# dtype('float64')

# %%
#concat dfs
ensemble=pd.concat(ensemble_list,ignore_index=True)
#groupby to get ensemble mean
ensemble_mean=ensemble.groupby('Year Counter')['tas'].mean()
print(ensemble_mean)
#groupby to get ensemble std deviation
ensemble_std=ensemble.groupby('Year Counter')['tas'].std()
#plot
plt.figure()
ensemble_mean.plot()
plt.show()
plt.close()

plt.figure()
ensemble_std.plot()
plt.show()
plt.close()
ensemble.head()
# Out:
# Year Counter
# 1     283.402945
# 2     283.338573
# 3     283.326644
# 4     283.371669
# 5     283.368441
# 6     283.394322
# 7     283.389508
# 8     283.356819
# 9     283.377559
# 10    283.363093
# Name: tas, dtype: float64
#          time         tas  year  Year Counter  Trajectory ID
# 0  16160215.5  280.848658  1616             1              0
# 1  16160315.5  281.529713  1616             1              0
# 2  16160415.5  282.754529  1616             1              0
# 3  16160515.5  284.477558  1616             1              0
# 4  16160615.5  285.603778  1616             1              0
